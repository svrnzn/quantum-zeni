# %%
import numpy as np
import pickle
import dimer_stages as stages_dim
import stages_gutzwiller as stages_gutz
import matplotlib.pyplot as plt

# %%
import dimer_stages_myte_config as config

sim_list = config.sim_list


pstates_infty_full = []
states_infty_gutz_mc = []
thetas_gutz = []
prob_infty_gutz = []
for sim in sim_list:
    f = open(f"data/dimer-myte-lmbd_1={sim.lmbd_1:.1f}-lmbd_2={sim.lmbd_2:.1f}-Nt={sim.Nt}-T={sim.T}-dt={sim.dt}.pkl", "rb")
    data_full = pickle.load(f)
    f.close()

    f = open(f"data/gutzwiller-lambda={sim.lmbd_2}-Nt=10000T=10-dt={sim.dt}-omega0=1.pkl", "rb")
    data_gutz_mc = pickle.load(f)
    f.close()

    f = open(f"data/gutzwiller-analytical-lambda={sim.lmbd_2}.pkl", "rb")
    data_gutz = pickle.load(f)
    f.close()

    def flatten(L):
        return [i for l in L for i in l]
    
    states_infty_full = flatten(data_full[1][:100])
    # states_infty_full = data_full[1].flatten()
    pstates = []
    for state in states_infty_full:
        pstates.append(state.ptrace(0))
        
    pstates_infty_full.append(pstates)

    states_infty_gutz_mc.append(data_gutz_mc[1])

    thetas_gutz.append(data_gutz[1])
    prob_infty_gutz.append(data_gutz[2])

# %%
plt.style.use(["./config/stylelib/thesis.mplstyle"])

for i, sim in enumerate(sim_list):
    plt.figure()

    thetas_full = []
    for pstate_full in pstates_infty_full[i]:
        thetas_full.append(stages_dim.state_to_theta(pstate_full))

    thetas_gutz_mc = []
    for state in states_infty_gutz_mc[i]:
        thetas_gutz_mc.append(stages_gutz.state_to_theta(state))

    counts_full, bins_full = np.histogram(thetas_full, 36)
    bin_width_full = bins_full[1] - bins_full[0]
    freqs_full = counts_full / np.sum(counts_full) / bin_width_full

    counts_gutz_mc, bins_gutz_mc = np.histogram(thetas_gutz_mc, 36)
    bin_width_gutz_mc = bins_gutz_mc[1] - bins_gutz_mc[0]
    freqs_gutz_mc = counts_gutz_mc / np.sum(counts_gutz_mc) / bin_width_gutz_mc


    plt.plot(bins_full[:-1] + bin_width_full/2, freqs_full, ".", label=rf"Full MC")
    plt.plot(bins_gutz_mc[:-1] + bin_width_gutz_mc/2, freqs_gutz_mc, ".", label=rf"Gutzwiller MC")
    plt.plot(thetas_gutz[i], prob_infty_gutz[i], label="Gutzwiller ``analytical''")

    plt.xlim((-np.pi, np.pi))
    xticks = [-np.pi, -np.pi/2, 0, np.pi/2, np.pi]
    xlabels = [r"$-\pi$", r"$-\pi/2$", r"$0$", r"$\pi/2$", r"$\pi$"]
    plt.xticks(xticks, xlabels)
    plt.xlabel(r"$\theta$")
    plt.ylabel(r"$P_\infty(\theta)$")
    plt.legend(loc="upper left")
    plt.title(rf"$\lambda = {sim.lmbd_2}$")

    plt.tight_layout()

    # plt.savefig(f"plots/Ns={sim.Ns}-lambda={sim.lmbd}-Nt={sim.Nt}T={sim.T}-dt={sim.dt}.pdf")

# %%
import qutip

# %%
pstates_infty_full[0][-20:]
# Out:
# [Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.30041164+0.j         0.        -0.44743696j]
#   [0.        +0.44743696j 0.69958836+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.81974439+0.j         0.        -0.28959879j]
#   [0.        +0.28959879j 0.18025561+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.43150017+0.j         0.        -0.46949395j]
#   [0.        +0.46949395j 0.56849983+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.86804111+0.j         0.        -0.24603429j]
#   [0.        +0.24603429j 0.13195889+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.9572401+0.j         0.       +0.18627506j]
#   [0.       -0.18627506j 0.0427599+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.63235171+0.j         0.        +0.44668418j]
#   [0.        -0.44668418j 0.36764829+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.40561347+0.j         0.        +0.26513036j]
#   [0.        -0.26513036j 0.59438653+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.62324686+0.j         0.        -0.08434571j]
#   [0.        +0.08434571j 0.37675314+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.9367797+0.j         0.       +0.14588924j]
#   [0.       -0.14588924j 0.0632203+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.63072463+0.j         0.        +0.43206407j]
#   [0.        -0.43206407j 0.36927537+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.40938412+0.j         0.        +0.24226853j]
#   [0.        -0.24226853j 0.59061588+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.64789432+0.j         0.        -0.09508062j]
#   [0.        +0.09508062j 0.35210568+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.93416426+0.j         0.        +0.16575366j]
#   [0.        -0.16575366j 0.06583574+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.61713156+0.j         0.        +0.43275727j]
#   [0.        -0.43275727j 0.38286844+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.40839419+0.j         0.        +0.22928798j]
#   [0.        -0.22928798j 0.59160581+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.66576112+0.j         0.        -0.10003889j]
#   [0.        +0.10003889j 0.33423888+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.92955471+0.j        0.        +0.1839207j]
#   [0.        -0.1839207j 0.07044529+0.j       ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.6040607+0.j       0.       +0.432337j]
#   [0.       -0.432337j 0.3959393+0.j      ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.01075217+0.j         0.        -0.10311251j]
#   [0.        +0.10311251j 0.98924783+0.j        ]],
#  Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
#  Qobj data =
#  [[0.61040377+0.j         0.        -0.42614063j]
#   [0.        +0.42614063j 0.38959623+0.j        ]]]

# %%
b = qutip.Bloch()

b.add_states(pstates_infty_full[0][:6])
b.render()

# %%
b

# %%
len(pstates_infty_full[0])
# Out:
# 10100
